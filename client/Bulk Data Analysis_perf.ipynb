# %%
# %load_ext sql

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import peakutils
import locate
import farwave
import time

from scipy import signal

MIC_IND_LR = {
    0: (1, 2),
    1: (2, 0),
    2: (0, 1)
}

ANGLE_OFFSET = {
    0: 0,
    1: 2.0944, # 120 deg in rad
    2: 4.18879, # 240 deg in rad
}

# %%
# %matplotlib notebook

# %%
# %sql sqlite:///schema/sunday_cardboard.db
# Out:
# u'Connected: None@schema/sunday_cardboard.db'

# %%
l = 0.3 # Length from mic to centre of array

def calc_delays(sigs, offsets):
    """ Calculate matrix of delays given N sigs
    """
    results = []
    for j in range(len(sigs)):
        for k in range(len(sigs)):
            if j != k:
                results.append((
                        (j, k), locate.xcorr_peaks(sigs[j], sigs[k], offsets[j], offsets[k], l)
                    ))
            

    # 3x3 array delays[i][j] is the delay of signal j relative to signal i
    delays = np.zeros((len(sigs), len(sigs)), dtype=np.float)
    for res in results:
        key, val = res[0], res[1]
        delays[key[0]][key[1]] = val[1] # xcorr (val, delay) tuple
        delays[key[1]][key[0]] = -delays[key[0]][key[1]]
        
    return delays

def calc_angles(sigs, delays, l):
    """ Given delays matrix, calculate angle using both farwave and solver
    """
    # Estimate "location" of sound source, create array record
    theta = 0             
    for j in range(len(sigs)):
        if delays[j][(j+1)%3] >= 0 and delays[j][(j+2)%3] >= 0:
            lr = MIC_IND_LR[j]
            near_pair = (min(j, lr[0]), max(j, lr[0])) if delays[j][lr[0]] < delays[j][lr[1]] else (min(j, lr[1]), max(j, lr[1]))
            print 'Near Pair: %r' %  str(near_pair)
            f_theta = np.deg2rad(farwave.calc_angle(delays, l, near_pair=near_pair))
            print 'Using microphone %d as closest mic - (%d left, %d right)' % (j, lr[0], lr[1])
            r, theta = 0, 0 #locate.locate(delays[j][lr[0]], delays[j][lr[1]], l, r0=5., theta0=f_theta-ANGLE_OFFSET[j])
            theta += ANGLE_OFFSET[j]
            print 'Solver: r = %f, theta = %f' % (r, np.rad2deg(theta))
            break
    
    return np.rad2deg(theta), np.rad2deg(f_theta)

# %%
experiments = %sql select id, comment from experiment
# Out:
# Done.

# %%
ang_solver_raw = []
ang_solver_butter = []
ang_far_raw = []
ang_far_butter = []

for i in range(len(experiments)):
    cur_experiment_id = int(experiments[i][0])
    result = %sql select data from mic where experiment_id = :cur_experiment_id and array_id = 0
        
    mic_0 = np.array(result[0][0])
    mic_1 = np.array(result[1][0])
    mic_2 = np.array(result[2][0])
    
    bufs = [mic_0, mic_1, mic_2]
    #try:
    try: 
        sigs, sigs_filt = [], []
        for buf_i in bufs:
            sig, sig_filt = locate.preprocess_sig(buf_i)
            sigs.append(sig)
            sigs_filt.append(sig_filt)
                
        sigs_cropped, sigs_butter_cropped, offsets, _, _ = locate.crop_sigs_npeaks(sigs, sigs_filt)
    except RuntimeError as e:
        print 'Error: %s' % str(e)
        solver_raw = solver_butter = far_raw = far_butter = 0
        ang_solver_raw.append(solver_raw)
        ang_solver_butter.append(solver_butter)
        ang_far_raw.append(far_raw)
        ang_far_butter.append(far_butter)
        continue
        
    # Calculate delays, angle using raw signal (cropped)
    delays_raw = calc_delays(sigs_cropped, offsets)
    solver_raw, far_raw = calc_angles(sigs_cropped, delays_raw, l)

    delays_butter = calc_delays(sigs_butter_cropped, offsets)
    solver_butter, far_butter = calc_angles(sigs_butter_cropped, delays_butter, l)
    #except:
    #    print 'Failure to find peaks: Setting to 0'
    #    solver_raw = far_raw = solver_butter = far_butter = 0
        
    print 'ID: %d, %f,%f,%f,%f' % (cur_experiment_id, far_raw, far_butter, solver_raw, solver_butter)
    
    ang_solver_raw.append(solver_raw)
    ang_solver_butter.append(solver_butter)
    ang_far_raw.append(far_raw)
    ang_far_butter.append(far_butter)
# Out:
# Done.
# Near Pair: '(0, 2)'
# Angles: [11.707039944049448, 347.335066534627, 359.34489092913606]
# Errors: [1.5030314132153986, 1.4755579237395815, 1.0000653695691588]
#
# DEL_ERR: 0.027473
# Error: 0.027473, 1.000065, 'False'
# DEL_ERR: 0.502966
# Error: 0.502966, 1.000065, 'True'
# DEL_ERR: 0.475493
# Error: 0.475493, 1.000065, 'True'
# Angle (CCW): 359.355950
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 2)'
# Angles: [10.899881992708337, 348.32262614676409, 359.49091360987421]
# Errors: [1.527325556529274, 1.5039053682124877, 1.0000394749873351]
#
# DEL_ERR: 0.023420
# Error: 0.023420, 1.000039, 'False'
# DEL_ERR: 0.527286
# Error: 0.527286, 1.000039, 'True'
# DEL_ERR: 0.503866
# Error: 0.503866, 1.000039, 'True'
# Angle (CCW): 359.489288
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 1, 359.355950,359.489288,0.000000,0.000000
# Done.
# Near Pair: '(0, 2)'
# Angles: [21.641451949378286, 338.02213686572725, 359.73164693335974]
# Errors: [1.2752781883033677, 1.2694014893698513, 1.0000109683634857]
#
# DEL_ERR: 0.005877
# Error: 0.005877, 1.000011, 'False'
# DEL_ERR: 0.275267
# Error: 0.275267, 1.000011, 'True'
# DEL_ERR: 0.269391
# Error: 0.269391, 1.000011, 'True'
# Angle (CCW): 359.752469
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 2)'
# Angles: [24.150365974082952, 335.67455399101061, 359.85793110326335]
# Errors: [1.2337198646719503, 1.2310076945241957, 1.0000030741415993]
#
# DEL_ERR: 0.002712
# Error: 0.002712, 1.000003, 'False'
# DEL_ERR: 0.233717
# Error: 0.233717, 1.000003, 'True'
# DEL_ERR: 0.231005
# Error: 0.231005, 1.000003, 'True'
# Angle (CCW): 359.870150
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 2, 359.752469,359.870150,0.000000,0.000000
# Done.
# Near Pair: '(0, 1)'
# Angles: [22.282810028249056, 345.31763787969169, 5.692108599148913]
# Errors: [1.264158534444168, 1.4221193591103174, 1.0049551929431084]
#
# DEL_ERR: 0.157961
# Error: 0.157961, 1.004955, 'False'
# DEL_ERR: 0.259203
# Error: 0.259203, 1.004955, 'True'
# DEL_ERR: 0.417164
# Error: 0.417164, 1.004955, 'True'
# Angle (CCW): 5.422860
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 1)'
# Angles: [23.862589547025966, 342.57141606584491, 4.974707958390545]
# Errors: [1.2382290779746605, 1.357893686923101, 1.0037811692456446]
#
# DEL_ERR: 0.119665
# Error: 0.119665, 1.003781, 'False'
# DEL_ERR: 0.234448
# Error: 0.234448, 1.003781, 'True'
# DEL_ERR: 0.354113
# Error: 0.354113, 1.003781, 'True'
# Angle (CCW): 4.666675
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 3, 5.422860,4.666675,0.000000,0.000000
# Done.
# Near Pair: '(0, 2)'
# Angles: [12.932119898758106, 324.55296098141213, 341.53677782639062]
# Errors: [1.4681454484318328, 1.0994114635986327, 1.054266095533578]
#
# DEL_ERR: 0.368734
# Error: 0.368734, 1.054266, 'False'
# DEL_ERR: 0.413879
# Error: 0.413879, 1.054266, 'True'
# DEL_ERR: 0.045145
# Error: 0.045145, 1.054266, 'True'
# Setting final_ang to 324.552961
# Angle (CCW): 324.552961
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 2)'
# Angles: [14.805696099686573, 323.73127771052231, 342.11412691967655]
# Errors: [1.419034001817011, 1.0923672613653783, 1.0507842370023792]
#
# DEL_ERR: 0.326667
# Error: 0.326667, 1.050784, 'False'
# DEL_ERR: 0.368250
# Error: 0.368250, 1.050784, 'True'
# DEL_ERR: 0.041583
# Error: 0.041583, 1.050784, 'True'
# Setting final_ang to 323.731278
# Angle (CCW): 323.731278
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 4, 324.552961,323.731278,0.000000,0.000000
# Done.
# Near Pair: '(0, 2)'
# Angles: [11.206333098929747, 325.68182904922276, 341.40358978290544]
# Errors: [1.5179744344921378, 1.1096137392594052, 1.055087832220909]
#
# DEL_ERR: 0.408361
# Error: 0.408361, 1.055088, 'False'
# DEL_ERR: 0.462887
# Error: 0.462887, 1.055088, 'True'
# DEL_ERR: 0.054526
# Error: 0.054526, 1.055088, 'True'
# Setting final_ang to 325.681829
# Angle (CCW): 325.681829
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 2)'
# Angles: [12.548343191394046, 324.80485744500163, 341.50765180136875]
# Errors: [1.4788260723840256, 1.1016347088374674, 1.0544451997068771]
#
# DEL_ERR: 0.377191
# Error: 0.377191, 1.054445, 'False'
# DEL_ERR: 0.424381
# Error: 0.424381, 1.054445, 'True'
# DEL_ERR: 0.047190
# Error: 0.047190, 1.054445, 'True'
# Setting final_ang to 324.804857
# Angle (CCW): 324.804857
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 5, 325.681829,324.804857,0.000000,0.000000
# Done.
# Near Pair: '(0, 2)'
# Angles: [11.606104726657312, 325.64242520222814, 341.63244287649098]
# Errors: [1.5060107487745205, 1.1092471602548244, 1.0536801670038027]
#
# DEL_ERR: 0.396764
# Error: 0.396764, 1.053680, 'False'
# DEL_ERR: 0.452331
# Error: 0.452331, 1.053680, 'True'
# DEL_ERR: 0.055567
# Error: 0.055567, 1.053680, 'True'
# Setting final_ang to 325.642425
# Angle (CCW): 325.642425
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 2)'
# Angles: [12.955290151221314, 324.67884560409794, 341.6781769676183]
# Errors: [1.4675076512849992, 1.1005187430387628, 1.0534013224159722]
#
# DEL_ERR: 0.366989
# Error: 0.366989, 1.053401, 'False'
# DEL_ERR: 0.414106
# Error: 0.414106, 1.053401, 'True'
# DEL_ERR: 0.047117
# Error: 0.047117, 1.053401, 'True'
# Setting final_ang to 324.678846
# Angle (CCW): 324.678846
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 6, 325.642425,324.678846,0.000000,0.000000
# Done.
# Near Pair: '(0, 2)'
# Angles: [286.08612947450035, 294.87870834715136, 305.93847922774137]
# Errors: [1.4418025549745919, 1.0040080375577851, 1.7038206346580742]
#
# DEL_ERR: 0.437795
# Error: 0.437795, 1.004008, 'True'
# DEL_ERR: 0.262018
# Error: 0.262018, 1.004008, 'False'
# DEL_ERR: 0.699813
# Error: 0.699813, 1.004008, 'True'
# Angle (CCW): 294.851317
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [285.30080381991598, 294.33168636391378, 305.94520256329952]
# Errors: [1.4216970547219394, 1.0049136814777486, 1.7035448835924833]
#
# DEL_ERR: 0.416783
# Error: 0.416783, 1.004914, 'True'
# DEL_ERR: 0.281848
# Error: 0.281848, 1.004914, 'False'
# DEL_ERR: 0.698631
# Error: 0.698631, 1.004914, 'True'
# Angle (CCW): 294.312880
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 7, 294.851317,294.312880,239.999988,239.999988
# Done.
# Near Pair: '(0, 2)'
# Angles: [287.03891885811083, 294.86285946515693, 304.79299573319958]
# Errors: [1.4673483693047558, 1.0040329668120218, 1.752500704691236]
#
# DEL_ERR: 0.463315
# Error: 0.463315, 1.004033, 'True'
# DEL_ERR: 0.285152
# Error: 0.285152, 1.004033, 'False'
# DEL_ERR: 0.748468
# Error: 0.748468, 1.004033, 'True'
# Angle (CCW): 294.815745
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [286.09751037571391, 294.70831202035993, 305.63479297944122]
# Errors: [1.4421001052360558, 1.004280153533496, 1.7163945652180586]
#
# DEL_ERR: 0.437820
# Error: 0.437820, 1.004280, 'True'
# DEL_ERR: 0.274294
# Error: 0.274294, 1.004280, 'False'
# DEL_ERR: 0.712114
# Error: 0.712114, 1.004280, 'True'
# Angle (CCW): 294.676160
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 8, 294.815745,294.676160,239.999988,239.999988
# Done.
# Near Pair: '(0, 2)'
# Angles: [285.55947871125625, 295.20748583150947, 307.10556598318919]
# Errors: [1.4282277114120885, 1.0035084829601368, 1.6575900736831763]
#
# DEL_ERR: 0.424719
# Error: 0.424719, 1.003508, 'True'
# DEL_ERR: 0.229362
# Error: 0.229362, 1.003508, 'False'
# DEL_ERR: 0.654082
# Error: 0.654082, 1.003508, 'True'
# Angle (CCW): 295.202085
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [285.54257237721373, 295.22728654462378, 307.15786593558494]
# Errors: [1.427798162250288, 1.0034794677335994, 1.6555929552151085]
#
# DEL_ERR: 0.424319
# Error: 0.424319, 1.003479, 'True'
# DEL_ERR: 0.227795
# Error: 0.227795, 1.003479, 'False'
# DEL_ERR: 0.652113
# Error: 0.652113, 1.003479, 'True'
# Angle (CCW): 295.222764
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 9, 295.202085,295.222764,239.999988,239.999988
# Done.
# Error: Error invalid index in [ 7786 41865]
# Done.
# Near Pair: '(0, 2)'
# Angles: [262.06051080980421, 267.44791050191924, 245.9471086519174]
# Errors: [1.0789957489009365, 1.186376665342451, 2.4535073291180534]
#
# DEL_ERR: 0.107381
# Error: 0.107381, 1.078996, 'True'
# Setting final_ang to 267.447911
# DEL_ERR: 1.267131
# Error: 1.267131, 1.078996, 'False'
# Angle (CCW): 267.447911
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [262.45280326474938, 267.92420225070492, 245.86976631234722]
# Errors: [1.08202337713301, 1.1801550136919312, 2.4461116379379844]
#
# DEL_ERR: 0.098132
# Error: 0.098132, 1.082023, 'True'
# Setting final_ang to 267.924202
# DEL_ERR: 1.265957
# Error: 1.265957, 1.082023, 'False'
# Angle (CCW): 267.924202
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 11, 267.447911,267.924202,239.999988,239.999988
# Done.
# Near Pair: '(0, 2)'
# Angles: [267.31342382959656, 268.87866992957959, 257.32775415969786]
# Errors: [1.1254800508282194, 1.168122319991135, 4.558433063007883]
#
# DEL_ERR: 0.042642
# Error: 0.042642, 1.125480, 'True'
# Setting final_ang to 268.878670
# DEL_ERR: 3.390311
# Error: 3.390311, 1.125480, 'False'
# Angle (CCW): 268.878670
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [266.47268599637187, 269.39816532894031, 252.76849439622396]
# Errors: [1.1171349871997194, 1.1618102830981163, 3.3757178285877836]
#
# DEL_ERR: 0.044675
# Error: 0.044675, 1.117135, 'True'
# Setting final_ang to 269.398165
# DEL_ERR: 2.213908
# Error: 2.213908, 1.117135, 'False'
# Angle (CCW): 269.398165
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 12, 268.878670,269.398165,239.999988,239.999988
# Done.
# Near Pair: '(0, 2)'
# Angles: [263.48578867665913, 267.8962541195483, 248.37739416082059]
# Errors: [1.0903235479269324, 1.1805160391749407, 2.7137678054904253]
#
# DEL_ERR: 0.090192
# Error: 0.090192, 1.090324, 'True'
# Setting final_ang to 267.896254
# DEL_ERR: 1.533252
# Error: 1.533252, 1.090324, 'False'
# Angle (CCW): 267.896254
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [263.57617855620146, 267.92885944178232, 248.49550574848709]
# Errors: [1.0910728305627395, 1.1800949022622775, 2.727960616719987]
#
# DEL_ERR: 0.089022
# Error: 0.089022, 1.091073, 'True'
# Setting final_ang to 267.928859
# DEL_ERR: 1.547866
# Error: 1.547866, 1.091073, 'False'
# Angle (CCW): 267.928859
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 13, 267.896254,267.928859,239.999988,239.999988
# Done.
# locate.py:360: RuntimeWarning: invalid value encountered in divide
#   CORR = CORR / (np.abs(SIG1) * np.abs(np.conj(SIG2)))
# Near Pair: '(1, 2)'
# Angles: [251.44944104353004, 210.54680969489701, 269.45319030510302]
# Errors: [1.0203037909921615, 104.78352855705414, 104.78352855705414]
#
# DEL_ERR: 103.763225
# Error: 103.763225, 1.020304, 'True'
# DEL_ERR: 103.763225
# Error: 103.763225, 1.020304, 'True'
# DEL_ERR: 0.000000
# Error: 0.000000, 1.020304, 'False'
# Angle (CCW): 246.121260
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(0, 2)'
# Angles: [252.32457484542391, 278.23724394906043, 226.04631479455676]
# Errors: [1.023589528312158, 1.076742645441642, 1.4407630245727059]
#
# DEL_ERR: 0.053153
# Error: 0.053153, 1.023590, 'True'
# Setting final_ang to 278.237244
# DEL_ERR: 0.364020
# Error: 0.364020, 1.023590, 'False'
# Angle (CCW): 278.237244
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 14, 246.121260,278.237244,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [237.85268066908992, 242.07827993192518, 234.06152077225863]
# Errors: [1.0007027037093474, 1.882964674529475, 1.7038206346580742]
#
# DEL_ERR: 0.882262
# Error: 0.882262, 1.000703, 'True'
# DEL_ERR: 0.703118
# Error: 0.703118, 1.000703, 'True'
# DEL_ERR: 0.179144
# Error: 0.179144, 1.000703, 'False'
# Angle (CCW): 237.802802
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [239.29358470140366, 242.74095663906616, 235.59620505377677]
# Errors: [1.0000760102987931, 1.8489697940164507, 1.7698436771047994]
#
# DEL_ERR: 0.848894
# Error: 0.848894, 1.000076, 'True'
# DEL_ERR: 0.769768
# Error: 0.769768, 1.000076, 'True'
# DEL_ERR: 0.079126
# Error: 0.079126, 1.000076, 'False'
# Angle (CCW): 239.155101
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 15, 237.802802,239.155101,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [241.74850629446138, 264.10166405701358, 215.52894688659771]
# Errors: [1.0004658302582723, 1.234478484944746, 1.2287698783470717]
#
# DEL_ERR: 0.234013
# Error: 0.234013, 1.000466, 'True'
# DEL_ERR: 0.228304
# Error: 0.228304, 1.000466, 'True'
# DEL_ERR: 0.005709
# Error: 0.005709, 1.000466, 'False'
# Angle (CCW): 240.541113
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [231.63163264347855, 276.02708896298361, 197.40135672059725]
# Errors: [1.0107617484032307, 1.094406027946896, 1.0479618090704355]
#
# DEL_ERR: 0.083644
# Error: 0.083644, 1.010762, 'True'
# Setting final_ang to 197.401357
# DEL_ERR: 0.046444
# Error: 0.046444, 1.010762, 'False'
# Angle (CCW): 197.401357
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 16, 240.541113,197.401357,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [220.44317392603816, 239.04317123377388, 212.65514969749685]
# Errors: [1.061221939108054, 2.0598659195991016, 1.1877423803194525]
#
# DEL_ERR: 0.998644
# Error: 0.998644, 1.061222, 'True'
# DEL_ERR: 0.126520
# Error: 0.126520, 1.061222, 'True'
# Setting final_ang to 212.655150
# DEL_ERR: 0.872124
# Error: 0.872124, 1.061222, 'False'
# Angle (CCW): 212.655150
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [221.09936282216938, 241.89949430398326, 211.67150239413544]
# Errors: [1.056991103671617, 1.892395222281938, 1.1749882207251545]
#
# DEL_ERR: 0.835404
# Error: 0.835404, 1.056991, 'True'
# DEL_ERR: 0.117997
# Error: 0.117997, 1.056991, 'True'
# Setting final_ang to 211.671502
# DEL_ERR: 0.717407
# Error: 0.717407, 1.056991, 'False'
# Angle (CCW): 211.671502
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 17, 212.655150,211.671502,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [219.72541736821509, 240.48212600305021, 211.01536321017764]
# Errors: [1.0660494964528542, 1.971338534186725, 1.166821430340844]
#
# DEL_ERR: 0.905289
# Error: 0.905289, 1.066049, 'True'
# DEL_ERR: 0.100772
# Error: 0.100772, 1.066049, 'True'
# Setting final_ang to 211.015363
# DEL_ERR: 0.804517
# Error: 0.804517, 1.066049, 'False'
# Angle (CCW): 211.015363
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [220.52272552876039, 240.37303510032967, 211.95943897480797]
# Errors: [1.0606998014498064, 1.9777394097202776, 1.178657308305245]
#
# DEL_ERR: 0.917040
# Error: 0.917040, 1.060700, 'True'
# DEL_ERR: 0.117958
# Error: 0.117958, 1.060700, 'True'
# Setting final_ang to 211.959439
# DEL_ERR: 0.799082
# Error: 0.799082, 1.060700, 'False'
# Angle (CCW): 211.959439
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 18, 211.015363,211.959439,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [221.4743588505298, 240.96873616330799, 212.66921256007532]
# Errors: [1.054650335911699, 1.9433691388240717, 1.1879292780752189]
#
# DEL_ERR: 0.888719
# Error: 0.888719, 1.054650, 'True'
# DEL_ERR: 0.133279
# Error: 0.133279, 1.054650, 'True'
# Setting final_ang to 212.669213
# DEL_ERR: 0.755440
# Error: 0.755440, 1.054650, 'False'
# Angle (CCW): 212.669213
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [221.54509863955491, 241.31973113879502, 212.52868323665248]
# Errors: [1.0542149896972848, 1.9237675041619295, 1.186067466347594]
#
# DEL_ERR: 0.869553
# Error: 0.869553, 1.054215, 'True'
# DEL_ERR: 0.131852
# Error: 0.131852, 1.054215, 'True'
# Setting final_ang to 212.528683
# DEL_ERR: 0.737700
# Error: 0.737700, 1.054215, 'False'
# Angle (CCW): 212.528683
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 19, 212.669213,212.528683,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [221.3327912921973, 242.06341516417331, 211.8339368495399]
# Errors: [1.0555274857607668, 1.8837444761190674, 1.1770516046437758]
#
# DEL_ERR: 0.828217
# Error: 0.828217, 1.055527, 'True'
# DEL_ERR: 0.121524
# Error: 0.121524, 1.055527, 'True'
# Setting final_ang to 211.833937
# DEL_ERR: 0.706693
# Error: 0.706693, 1.055527, 'False'
# Angle (CCW): 211.833937
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [221.93157502010612, 242.70445510549885, 212.09442888682045]
# Errors: [1.0518711344065534, 1.8508039144219928, 1.1803956293258668]
#
# DEL_ERR: 0.798933
# Error: 0.798933, 1.051871, 'True'
# DEL_ERR: 0.128524
# Error: 0.128524, 1.051871, 'True'
# Setting final_ang to 212.094429
# DEL_ERR: 0.670408
# Error: 0.670408, 1.051871, 'False'
# Angle (CCW): 212.094429
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 20, 211.833937,212.094429,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [221.52429585004489, 242.80656843546029, 211.5741780281615]
# Errors: [1.0543428099274967, 1.8456839521516912, 1.1737598977623915]
#
# DEL_ERR: 0.791341
# Error: 0.791341, 1.054343, 'True'
# DEL_ERR: 0.119417
# Error: 0.119417, 1.054343, 'True'
# Setting final_ang to 211.574178
# DEL_ERR: 0.671924
# Error: 0.671924, 1.054343, 'False'
# Angle (CCW): 211.574178
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [221.89005954891721, 243.42059260087174, 211.58807528102432]
# Errors: [1.0521201190475413, 1.8156044649840466, 1.1739349294183703]
#
# DEL_ERR: 0.763484
# Error: 0.763484, 1.052120, 'True'
# DEL_ERR: 0.121815
# Error: 0.121815, 1.052120, 'True'
# Setting final_ang to 211.588075
# DEL_ERR: 0.641670
# Error: 0.641670, 1.052120, 'False'
# Angle (CCW): 211.588075
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 21, 211.574178,211.588075,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [221.64907485582026, 242.29313224167669, 212.03854685817501]
# Errors: [1.0535786656787758, 1.8717792706606702, 1.1796745973555152]
#
# DEL_ERR: 0.818201
# Error: 0.818201, 1.053579, 'True'
# DEL_ERR: 0.126096
# Error: 0.126096, 1.053579, 'True'
# Setting final_ang to 212.038547
# DEL_ERR: 0.692105
# Error: 0.692105, 1.053579, 'False'
# Angle (CCW): 212.038547
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [221.97723070730868, 244.00363869518816, 211.30590285515464]
# Errors: [1.0515980925656636, 1.7881232958450501, 1.1704047213212476]
#
# DEL_ERR: 0.736525
# Error: 0.736525, 1.051598, 'True'
# DEL_ERR: 0.118807
# Error: 0.118807, 1.051598, 'True'
# Setting final_ang to 211.305903
# DEL_ERR: 0.617719
# Error: 0.617719, 1.051598, 'False'
# Angle (CCW): 211.305903
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 22, 212.038547,211.305903,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [200.62776260266986, 169.20872953130882, 187.04620447549652]
# Errors: [1.2935923804249798, 1.5306780140350424, 1.0076099225363842]
#
# DEL_ERR: 0.237086
# Error: 0.237086, 1.007610, 'False'
# DEL_ERR: 0.285982
# Error: 0.285982, 1.007610, 'True'
# DEL_ERR: 0.523068
# Error: 0.523068, 1.007610, 'True'
# Angle (CCW): 186.842595
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [201.77218421169204, 168.1508019350066, 187.24108871467962]
# Errors: [1.2729827853011726, 1.4988630951067432, 1.0080395533635016]
#
# DEL_ERR: 0.225880
# Error: 0.225880, 1.008040, 'False'
# DEL_ERR: 0.264943
# Error: 0.264943, 1.008040, 'True'
# DEL_ERR: 0.490824
# Error: 0.490824, 1.008040, 'True'
# Angle (CCW): 186.978050
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 23, 186.842595,186.978050,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [201.08064125857715, 168.88360452364884, 187.18539900891483]
# Errors: [1.2852959426836315, 1.5207024134161309, 1.0079155555164836]
#
# DEL_ERR: 0.235406
# Error: 0.235406, 1.007916, 'False'
# DEL_ERR: 0.277380
# Error: 0.277380, 1.007916, 'True'
# DEL_ERR: 0.512787
# Error: 0.512787, 1.007916, 'True'
# Angle (CCW): 186.958893
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [201.9928901173364, 168.29296005595054, 187.51566095461752]
# Errors: [1.2691412686059926, 1.5030314132153986, 1.0086652953470858]
#
# DEL_ERR: 0.233890
# Error: 0.233890, 1.008665, 'False'
# DEL_ERR: 0.260476
# Error: 0.260476, 1.008665, 'True'
# DEL_ERR: 0.494366
# Error: 0.494366, 1.008665, 'True'
# Angle (CCW): 187.237878
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 24, 186.958893,187.237878,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [199.24582036687258, 167.2943207316947, 184.70935500075075]
# Errors: [1.3201017517372629, 1.474420617250322, 1.0033874410407664]
#
# DEL_ERR: 0.154319
# Error: 0.154319, 1.003387, 'False'
# DEL_ERR: 0.316714
# Error: 0.316714, 1.003387, 'True'
# DEL_ERR: 0.471033
# Error: 0.471033, 1.003387, 'True'
# Angle (CCW): 184.563159
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# Near Pair: '(1, 2)'
# Angles: [200.14108814328307, 166.61211189836152, 184.91925242129861]
# Errors: [1.3027195064935424, 1.455744134352031, 1.0036970797436253]
#
# DEL_ERR: 0.153025
# Error: 0.153025, 1.003697, 'False'
# DEL_ERR: 0.299022
# Error: 0.299022, 1.003697, 'True'
# DEL_ERR: 0.452047
# Error: 0.452047, 1.003697, 'True'
# Angle (CCW): 184.744954
# Using microphone 2 as closest mic - (0 left, 1 right)
# Solver: r = 0.000000, theta = 239.999988
# ID: 25, 184.563159,184.744954,239.999988,239.999988
# Done.
# Near Pair: '(1, 2)'
# Angles: [193.59431091744298, 143.71834574761198, 161.21611748871607]
# Errors: [1.4502261327177277, 1.0922589101212632, 1.0562563426827472]
#
# DEL_ERR: 0.357967
# Error: 0.357967, 1.056256, 'False'
# DEL_ERR: 0.393970
# Error: 0.393970, 1.056256, 'True'
# DEL_ERR: 0.036003
# Error: 0.036003, 1.056256, 'True'
# Setting final_ang to 161.216117
# Angle (CCW): 161.216117
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(1, 2)'
# Angles: [193.75432341459617, 143.03904941171433, 160.67334797751982]
# Errors: [1.4459903199679376, 1.0866750014781021, 1.0597181871223957]
#
# DEL_ERR: 0.359315
# Error: 0.359315, 1.059718, 'False'
# DEL_ERR: 0.386272
# Error: 0.386272, 1.059718, 'True'
# DEL_ERR: 0.026957
# Error: 0.026957, 1.059718, 'True'
# Setting final_ang to 160.673348
# Angle (CCW): 160.673348
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 26, 161.216117,160.673348,120.000281,120.000281
# Done.
# Near Pair: '(1, 2)'
# Angles: [191.53473563207166, 144.7831221460517, 160.765326637229]
# Errors: [1.5081273396696266, 1.1014416783766414, 1.0591232475105892]
#
# DEL_ERR: 0.406686
# Error: 0.406686, 1.059123, 'False'
# DEL_ERR: 0.449004
# Error: 0.449004, 1.059123, 'True'
# DEL_ERR: 0.042318
# Error: 0.042318, 1.059123, 'True'
# Setting final_ang to 160.765327
# Angle (CCW): 160.765327
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(1, 2)'
# Angles: [192.4373425224536, 144.0420322145395, 160.6900752146733]
# Errors: [1.4819567338535373, 1.0949942201347223, 1.0596097385273253]
#
# DEL_ERR: 0.386963
# Error: 0.386963, 1.059610, 'False'
# DEL_ERR: 0.422347
# Error: 0.422347, 1.059610, 'True'
# DEL_ERR: 0.035384
# Error: 0.035384, 1.059610, 'True'
# Setting final_ang to 160.690075
# Angle (CCW): 160.690075
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 27, 160.765327,160.690075,120.000281,120.000281
# Done.
# Near Pair: '(1, 2)'
# Angles: [194.36155768379751, 143.64939690930464, 161.70311773925025]
# Errors: [1.4302390644329848, 1.0916825190156652, 1.0532496013362116]
#
# DEL_ERR: 0.338557
# Error: 0.338557, 1.053250, 'False'
# DEL_ERR: 0.376989
# Error: 0.376989, 1.053250, 'True'
# DEL_ERR: 0.038433
# Error: 0.038433, 1.053250, 'True'
# Setting final_ang to 161.703118
# Angle (CCW): 161.703118
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(1, 2)'
# Angles: [194.9119970844088, 143.05620412195552, 161.5409382833932]
# Errors: [1.4163907242898703, 1.0868134355303132, 1.0542405389070917]
#
# DEL_ERR: 0.329577
# Error: 0.329577, 1.054241, 'False'
# DEL_ERR: 0.362150
# Error: 0.362150, 1.054241, 'True'
# DEL_ERR: 0.032573
# Error: 0.032573, 1.054241, 'True'
# Setting final_ang to 161.540938
# Angle (CCW): 161.540938
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 28, 161.703118,161.540938,120.000281,120.000281
# Done.
# Near Pair: '(1, 2)'
# Angles: [105.76841044644218, 126.28731382444813, 142.62624446946478]
# Errors: [1.433567905048938, 1.0060511684270368, 1.2583479635204002]
#
# DEL_ERR: 0.427517
# Error: 0.427517, 1.006051, 'True'
# DEL_ERR: 0.175220
# Error: 0.175220, 1.006051, 'False'
# DEL_ERR: 0.252297
# Error: 0.252297, 1.006051, 'True'
# Angle (CCW): 125.989065
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(1, 2)'
# Angles: [104.5040716647059, 125.86266824789526, 143.2247400431626]
# Errors: [1.40212998525651, 1.0052579194380067, 1.248455111995925]
#
# DEL_ERR: 0.396872
# Error: 0.396872, 1.005258, 'True'
# DEL_ERR: 0.153675
# Error: 0.153675, 1.005258, 'False'
# DEL_ERR: 0.243197
# Error: 0.243197, 1.005258, 'True'
# Angle (CCW): 125.552004
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 29, 125.989065,125.552004,120.000281,120.000281
# Done.
# Near Pair: '(1, 2)'
# Angles: [104.69806035088041, 122.01305477784373, 138.06836348806934]
# Errors: [1.40681941652317, 1.0006175318432189, 1.344189579214334]
#
# DEL_ERR: 0.406202
# Error: 0.406202, 1.000618, 'True'
# DEL_ERR: 0.062630
# Error: 0.062630, 1.000618, 'False'
# DEL_ERR: 0.343572
# Error: 0.343572, 1.000618, 'True'
# Angle (CCW): 121.942525
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(1, 2)'
# Angles: [103.87663918325381, 121.76035090950965, 138.54927920297587]
# Errors: [1.3872824008952727, 1.0004721653190465, 1.3341776848822373]
#
# DEL_ERR: 0.386810
# Error: 0.386810, 1.000472, 'True'
# DEL_ERR: 0.053105
# Error: 0.053105, 1.000472, 'False'
# DEL_ERR: 0.333706
# Error: 0.333706, 1.000472, 'True'
# Angle (CCW): 121.704143
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 30, 121.942525,121.704143,120.000281,120.000281
# Done.
# Near Pair: '(1, 2)'
# Angles: [109.41453865377008, 127.14960209030733, 140.58180270783132]
# Errors: [1.5370863588141426, 1.0078363694138588, 1.294444857334715]
#
# DEL_ERR: 0.529250
# Error: 0.529250, 1.007836, 'True'
# DEL_ERR: 0.242642
# Error: 0.242642, 1.007836, 'False'
# DEL_ERR: 0.286608
# Error: 0.286608, 1.007836, 'True'
# Angle (CCW): 126.946539
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(1, 2)'
# Angles: [108.16263338833761, 126.90307653990352, 141.3489632748836]
# Errors: [1.499208779406897, 1.0073020436596902, 1.2804680388995404]
#
# DEL_ERR: 0.491907
# Error: 0.491907, 1.007302, 'True'
# DEL_ERR: 0.218741
# Error: 0.218741, 1.007302, 'False'
# DEL_ERR: 0.273166
# Error: 0.273166, 1.007302, 'True'
# Angle (CCW): 126.669722
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 31, 126.946539,126.669722,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [86.32289058673649, 98.0161142380028, 125.13045092550095]
# Errors: [1.1156862369446892, 1.0784122443053328, 1.7378006638097456]
#
# DEL_ERR: 0.037274
# Error: 0.037274, 1.078412, 'True'
# Setting final_ang to 86.322891
# DEL_ERR: 0.659388
# Error: 0.659388, 1.078412, 'True'
# Angle (CCW): 86.322891
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(0, 1)'
# Angles: [86.12932468364515, 97.84577990583597, 125.1578735074941]
# Errors: [1.1138309726363562, 1.0797128364870812, 1.7366195610493649]
#
# DEL_ERR: 0.034118
# Error: 0.034118, 1.079713, 'True'
# Setting final_ang to 86.129325
# DEL_ERR: 0.656907
# Error: 0.656907, 1.079713, 'True'
# Angle (CCW): 86.129325
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 32, 86.322891,86.129325,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [85.53303820526763, 101.10353403146658, 130.89988199270832]
# Errors: [1.108233532687534, 1.056964760174737, 1.527325556529274]
#
# DEL_ERR: 0.051269
# Error: 0.051269, 1.056965, 'True'
# Setting final_ang to 85.533038
# DEL_ERR: 0.470361
# Error: 0.470361, 1.056965, 'True'
# Angle (CCW): 85.533038
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(0, 1)'
# Angles: [85.73438779500673, 100.45992488705112, 129.72872833976353]
# Errors: [1.11010389481449, 1.0611117812722994, 1.5645693451079077]
#
# DEL_ERR: 0.048992
# Error: 0.048992, 1.061112, 'True'
# Setting final_ang to 85.734388
# DEL_ERR: 0.503458
# Error: 0.503458, 1.061112, 'True'
# Angle (CCW): 85.734388
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 33, 85.533038,85.734388,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [87.34896186707546, 98.18199360357495, 123.7629653797064]
# Errors: [1.1258408988962827, 1.077157815051551, 1.799343118224013]
#
# DEL_ERR: 0.048683
# Error: 0.048683, 1.077158, 'True'
# Setting final_ang to 87.348962
# DEL_ERR: 0.722185
# Error: 0.722185, 1.077158, 'True'
# Angle (CCW): 87.348962
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(0, 1)'
# Angles: [86.71983439051768, 98.0076023893523, 124.43870157135603]
# Errors: [1.1195502916482725, 1.0784769361911086, 1.7682708814683263]
#
# DEL_ERR: 0.041073
# Error: 0.041073, 1.078477, 'True'
# Setting final_ang to 86.719834
# DEL_ERR: 0.689794
# Error: 0.689794, 1.078477, 'True'
# Angle (CCW): 86.719834
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 34, 87.348962,86.719834,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [60.90769943429498, 76.6466423982328, 44.6092994240412]
# Errors: [1.0001255030521392, 1.3752627795995171, 1.40466784811885]
#
# DEL_ERR: 0.375137
# Error: 0.375137, 1.000126, 'True'
# DEL_ERR: 0.404542
# Error: 0.404542, 1.000126, 'True'
# DEL_ERR: 0.029405
# Error: 0.029405, 1.000126, 'False'
# Angle (CCW): 60.877762
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(0, 1)'
# Angles: [62.43958396943715, 80.07422264879825, 43.16910965601729]
# Errors: [1.0009071611940732, 1.3039909528724019, 1.371107177086891]
#
# DEL_ERR: 0.303084
# Error: 0.303084, 1.000907, 'True'
# DEL_ERR: 0.370200
# Error: 0.370200, 1.000907, 'True'
# DEL_ERR: 0.067116
# Error: 0.067116, 1.000907, 'False'
# Angle (CCW): 62.318317
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 35, 60.877762,62.318317,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [62.838589738054736, 77.25686795630897, 46.738647221192046]
# Errors: [1.0012284977520653, 1.361648596298471, 1.4591568172160996]
#
# DEL_ERR: 0.360420
# Error: 0.360420, 1.001228, 'True'
# DEL_ERR: 0.457928
# Error: 0.457928, 1.001228, 'True'
# DEL_ERR: 0.097508
# Error: 0.097508, 1.001228, 'False'
# Angle (CCW): 62.765830
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(0, 1)'
# Angles: [63.39585241528328, 79.44868526696574, 45.21110641344105]
# Errors: [1.001758970105258, 1.3160942397853364, 1.4194531634617538]
#
# DEL_ERR: 0.314335
# Error: 0.314335, 1.001759, 'True'
# DEL_ERR: 0.417694
# Error: 0.417694, 1.001759, 'True'
# DEL_ERR: 0.103359
# Error: 0.103359, 1.001759, 'False'
# Angle (CCW): 63.277568
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 36, 62.765830,63.277568,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [61.97356734101009, 75.4461073260929, 47.387500241768684]
# Errors: [1.0005935309759366, 1.4033298247229418, 1.4770251501268898]
#
# DEL_ERR: 0.402736
# Error: 0.402736, 1.000594, 'True'
# DEL_ERR: 0.476432
# Error: 0.476432, 1.000594, 'True'
# DEL_ERR: 0.073695
# Error: 0.073695, 1.000594, 'False'
# Angle (CCW): 61.936464
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# Near Pair: '(0, 1)'
# Angles: [62.09203254005434, 77.81322928622602, 45.0880029155912]
# Errors: [1.0006669648132178, 1.3496011134934063, 1.4163907242898703]
#
# DEL_ERR: 0.348934
# Error: 0.348934, 1.000667, 'True'
# DEL_ERR: 0.415724
# Error: 0.415724, 1.000667, 'True'
# DEL_ERR: 0.066790
# Error: 0.066790, 1.000667, 'False'
# Angle (CCW): 62.027675
# Using microphone 1 as closest mic - (2 left, 0 right)
# Solver: r = 0.000000, theta = 120.000281
# ID: 37, 61.936464,62.027675,120.000281,120.000281
# Done.
# Near Pair: '(0, 1)'
# Angles: [36.570135910739026, 64.25684658173839, 25.393168192967565]
# Errors: [1.08986183639125, 1.7765028098374993, 1.106946003408894]
#
# DEL_ERR: 0.686641
# Error: 0.686641, 1.089862, 'True'
# DEL_ERR: 0.017084
# Error: 0.017084, 1.089862, 'True'
# Setting final_ang to 36.570136
# DEL_ERR: 0.669557
# Error: 0.669557, 1.089862, 'False'
# Angle (CCW): 36.570136
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 1)'
# Angles: [37.0509770399851, 65.32201947510472, 25.20983427059563]
# Errors: [1.085950684382007, 1.7295914119319857, 1.1052728655411745]
#
# DEL_ERR: 0.643641
# Error: 0.643641, 1.085951, 'True'
# DEL_ERR: 0.019322
# Error: 0.019322, 1.085951, 'True'
# Setting final_ang to 37.050977
# DEL_ERR: 0.624319
# Error: 0.624319, 1.085951, 'False'
# Angle (CCW): 37.050977
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 38, 36.570136,37.050977,0.000000,0.000000
# Done.
# Near Pair: '(0, 1)'
# Angles: [37.01668832522777, 64.24983524250057, 25.852730093484926]
# Errors: [1.086226127724269, 1.776822081931971, 1.1112125512103423]
#
# DEL_ERR: 0.690596
# Error: 0.690596, 1.086226, 'True'
# DEL_ERR: 0.024986
# Error: 0.024986, 1.086226, 'True'
# Setting final_ang to 37.016688
# DEL_ERR: 0.665610
# Error: 0.665610, 1.086226, 'False'
# Angle (CCW): 37.016688
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 1)'
# Angles: [37.18804522209692, 66.79042970843116, 24.401199277621423]
# Errors: [1.0848548791908081, 1.6697561566000512, 1.098086567516006]
#
# DEL_ERR: 0.584901
# Error: 0.584901, 1.084855, 'True'
# DEL_ERR: 0.013232
# Error: 0.013232, 1.084855, 'True'
# Setting final_ang to 37.188045
# DEL_ERR: 0.571670
# Error: 0.571670, 1.084855, 'False'
# Angle (CCW): 37.188045
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 39, 37.016688,37.188045,0.000000,0.000000
# Done.
# Near Pair: '(0, 1)'
# Angles: [36.62173761790001, 64.4944877598014, 25.297101555519056]
# Errors: [1.089437081443527, 1.7657644649762565, 1.106067238740924]
#
# DEL_ERR: 0.676327
# Error: 0.676327, 1.089437, 'True'
# DEL_ERR: 0.016630
# Error: 0.016630, 1.089437, 'True'
# Setting final_ang to 36.621738
# DEL_ERR: 0.659697
# Error: 0.659697, 1.089437, 'False'
# Angle (CCW): 36.621738
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# Near Pair: '(0, 1)'
# Angles: [37.068118138734015, 66.8167794042291, 24.26260515125694]
# Errors: [1.0858131870198506, 1.6687301302054185, 1.0968861277708282]
#
# DEL_ERR: 0.582917
# Error: 0.582917, 1.085813, 'True'
# DEL_ERR: 0.011073
# Error: 0.011073, 1.085813, 'True'
# Setting final_ang to 37.068118
# DEL_ERR: 0.571844
# Error: 0.571844, 1.085813, 'False'
# Angle (CCW): 37.068118
# Using microphone 0 as closest mic - (1 left, 2 right)
# Solver: r = 0.000000, theta = 0.000000
# ID: 40, 36.621738,37.068118,0.000000,0.000000

# %%
# Assuming comment is the _actual_ angle
for i in range(len(ang_solver_raw)):
    print '%f,%f,%f,%f,%s' % (ang_far_raw[i], ang_far_butter[i], ang_solver_raw[i], ang_solver_butter[i], experiments[i][1])
# Out:
# 359.355950,359.489288,0.000000,0.000000,0
# 359.752469,359.870150,0.000000,0.000000,0
# 5.422860,4.666675,0.000000,0.000000,0
# 324.552961,323.731278,0.000000,0.000000,30
# 325.681829,324.804857,0.000000,0.000000,30
# 325.642425,324.678846,0.000000,0.000000,30
# 294.851317,294.312880,239.999988,239.999988,60
# 294.815745,294.676160,239.999988,239.999988,60
# 295.202085,295.222764,239.999988,239.999988,60
# 0.000000,0.000000,0.000000,0.000000,90
# 267.447911,267.924202,239.999988,239.999988,90
# 268.878670,269.398165,239.999988,239.999988,90
# 267.896254,267.928859,239.999988,239.999988,90
# 246.121260,278.237244,239.999988,239.999988,120
# 237.802802,239.155101,239.999988,239.999988,120
# 240.541113,197.401357,239.999988,239.999988,120
# 212.655150,211.671502,239.999988,239.999988,150
# 211.015363,211.959439,239.999988,239.999988,150
# 212.669213,212.528683,239.999988,239.999988,150
# 211.833937,212.094429,239.999988,239.999988,150
# 211.574178,211.588075,239.999988,239.999988,150
# 212.038547,211.305903,239.999988,239.999988,150
# 186.842595,186.978050,239.999988,239.999988,180
# 186.958893,187.237878,239.999988,239.999988,180
# 184.563159,184.744954,239.999988,239.999988,180
# 161.216117,160.673348,120.000281,120.000281,-150
# 160.765327,160.690075,120.000281,120.000281,-150
# 161.703118,161.540938,120.000281,120.000281,-150
# 125.989065,125.552004,120.000281,120.000281,-120
# 121.942525,121.704143,120.000281,120.000281,-120
# 126.946539,126.669722,120.000281,120.000281,-120
# 86.322891,86.129325,120.000281,120.000281,-90
# 85.533038,85.734388,120.000281,120.000281,-90
# 87.348962,86.719834,120.000281,120.000281,-90
# 60.877762,62.318317,120.000281,120.000281,-60
# 62.765830,63.277568,120.000281,120.000281,-60
# 61.936464,62.027675,120.000281,120.000281,-60
# 36.570136,37.050977,0.000000,0.000000,-30
# 37.016688,37.188045,0.000000,0.000000,-30
# 36.621738,37.068118,0.000000,0.000000,-30
